# %% [markdown]
# # Assignment 4

# %%
import ml_pipeline as pp
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from sklearn.tree import DecisionTreeClassifier
from IPython.display import Image
import datetime as dt

# %% [markdown]
# ## Load data

# %%
filename = './data/projects_2012_2013.csv'
df = pp.load_csv(filename)
df.date_posted = pp.col_datetime(df, 'date_posted')
df.datefullyfunded = pp.col_datetime(df,'datefullyfunded')
df = pp.create_label(df, pred_time=60)

# %%
windows = [dt.datetime(2012,1,1), dt.datetime(2012,7,1), dt.datetime(2013,1,1), dt.datetime(2013,7,1), dt.datetime(2014,1,1)]
pred_time = 60 #days
label_col = 'label'
split_col = 'date_posted'

# %%
# pull data for final test set
x_train1, y_train1, x_test1, y_test1 = pp.single_train_test_set(df, df.columns, label_col, split_col, windows[0], windows[1], windows[2], pred_time, pred_unit = 'day')
x_train2, y_train2, x_test2, y_test2 = pp.single_train_test_set(df, df.columns, label_col, split_col, windows[0], windows[2], windows[3], pred_time, pred_unit = 'day')
x_train3, y_train3, x_test3, y_test3 = pp.single_train_test_set(df, df.columns, label_col, split_col, windows[0], windows[3], windows[4], pred_time, pred_unit = 'day')

# %% [markdown]
# ## Process data for clustering

# %% [markdown]
# ### Missing values

# %%
pp.na_col(df)
# Out:
# ['school_ncesid',
#  'school_metro',
#  'school_district',
#  'primary_focus_subject',
#  'primary_focus_area',
#  'secondary_focus_subject',
#  'secondary_focus_area',
#  'resource_type',
#  'grade_level',
#  'students_reached']

# %%
cat_col = ['school_metro',
 'school_district',
 'primary_focus_subject',
 'primary_focus_area',
 'secondary_focus_subject',
 'secondary_focus_area',
 'resource_type',
 'grade_level']
for c in cat_col:
    x_train1 = pp.na_fill_col(x_train1, c, pp.most_freq)
    x_train2 = pp.na_fill_col(x_train2, c, pp.most_freq)
    x_train3 = pp.na_fill_col(x_train3, c, pp.most_freq)
    x_test1 = pp.na_fill_col(x_test1, c, pp.most_freq)
    x_test2 =pp.na_fill_col(x_test2, c, pp.most_freq)
    x_test3=pp.na_fill_col(x_test3, c, pp.most_freq)
    df_all = pp.na_fill_col(df, c, pp.most_freq)

# %%
x_train1 = pp.na_fill_col(x_train1, 'students_reached', np.nanmean)
x_train2 = pp.na_fill_col(x_train2, 'students_reached', np.nanmean)
x_train3 = pp.na_fill_col(x_train3, 'students_reached', np.nanmean)
x_test1 = pp.na_fill_col(x_test1, 'students_reached', np.nanmean)
x_test2 =pp.na_fill_col(x_test2, 'students_reached', np.nanmean)
x_test3=pp.na_fill_col(x_test3, 'students_reached', np.nanmean)
df_all = pp.na_fill_col(df, 'students_reached', np.nanmean)

# %% [markdown]
# ### Categorical variables to binary

# %%
df_all = pp.feat_binary(df, ['school_metro','school_charter','primary_focus_subject','primary_focus_area', 'grade_level', 'resource_type'])

# %%
x_train1 = pp.feat_binary(x_train1, ['school_metro','school_charter','primary_focus_subject','primary_focus_area', 'grade_level', 'resource_type'])
x_train2 = pp.feat_binary(x_train2, ['school_metro','school_charter','primary_focus_subject','primary_focus_area', 'grade_level', 'resource_type'])
x_train3 = pp.feat_binary(x_train3, ['school_metro','school_charter','primary_focus_subject','primary_focus_area', 'grade_level', 'resource_type'])
x_test1 = pp.feat_binary(x_test1, ['school_metro','school_charter','primary_focus_subject','primary_focus_area', 'grade_level', 'resource_type'])
x_test2 = pp.feat_binary(x_test2, ['school_metro','school_charter','primary_focus_subject','primary_focus_area', 'grade_level', 'resource_type'])
x_test3 = pp.feat_binary(x_test3, ['school_metro','school_charter','primary_focus_subject','primary_focus_area', 'grade_level', 'resource_type'])

# %% [markdown]
# ### Normalization

# %%
num_col = ['total_price_including_optional_support', 'students_reached']

# %%
minmax1 = pp.normalize_mult_minmax(x_train1, num_col)
minmax2 = pp.normalize_mult_minmax(x_train2, num_col)
minmax3 = pp.normalize_mult_minmax(x_train3, num_col)
pp.normalize_mult_minmax(x_test1, num_col, minmax1)
pp.normalize_mult_minmax(x_test2, num_col, minmax2)
pp.normalize_mult_minmax(x_test3, num_col, minmax3)
pp.normalize_mult_minmax(df_all, num_col)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %% [markdown]
# ### Given a k, generate k clusters using KMeans

# %%
cat_feat = ['school_metro_rural',
 'school_metro_suburban',
 'school_metro_urban',
 'school_charter_f',
 'school_charter_t',
 'primary_focus_subject_Applied Sciences',
 'primary_focus_subject_Character Education',
 'primary_focus_subject_Civics & Government',
 'primary_focus_subject_College & Career Prep',
 'primary_focus_subject_Community Service',
 'primary_focus_subject_ESL',
 'primary_focus_subject_Early Development',
 'primary_focus_subject_Economics',
 'primary_focus_subject_Environmental Science',
 'primary_focus_subject_Extracurricular',
 'primary_focus_subject_Foreign Languages',
 'primary_focus_subject_Gym & Fitness',
 'primary_focus_subject_Health & Life Science',
 'primary_focus_subject_Health & Wellness',
 'primary_focus_subject_History & Geography',
 'primary_focus_subject_Literacy',
 'primary_focus_subject_Literature & Writing',
 'primary_focus_subject_Mathematics',
 'primary_focus_subject_Music',
 'primary_focus_subject_Nutrition',
 'primary_focus_subject_Other',
 'primary_focus_subject_Parent Involvement',
 'primary_focus_subject_Performing Arts',
 'primary_focus_subject_Social Sciences',
 'primary_focus_subject_Special Needs',
 'primary_focus_subject_Sports',
 'primary_focus_subject_Visual Arts',
 'primary_focus_area_Applied Learning',
 'primary_focus_area_Health & Sports',
 'primary_focus_area_History & Civics',
 'primary_focus_area_Literacy & Language',
 'primary_focus_area_Math & Science',
 'primary_focus_area_Music & The Arts',
 'primary_focus_area_Special Needs',
 'grade_level_Grades 3-5',
 'grade_level_Grades 6-8',
 'grade_level_Grades 9-12',
 'grade_level_Grades PreK-2',
 'resource_type_Books',
 'resource_type_Other',
 'resource_type_Supplies',
 'resource_type_Technology',
 'resource_type_Trips',
 'resource_type_Visitors']
num_feat = ['total_price_including_optional_support', 'students_reached']
features = cat_feat + num_feat

# %%
# rename columns so they can shown by export_graphviz
for c in df_final.columns:
    if '&' in c:
        new = c.replace(' & ', '')
        x_train1 = x_train1.rename(columns = {c:new})
        x_train2 = x_train2.rename(columns = {c:new})
        x_train3 = x_train3.rename(columns = {c:new})
        x_test1 = x_test1.rename(columns = {c:new})
        x_test2 = x_test2.rename(columns = {c:new})
        x_test3 = x_test3.rename(columns = {c:new})
        df_all = df_all.rename(columns = {c:new})
        features.remove(c)
        features.append(new)

# %%
# reset index
x_train1 = x_train1.reset_index()
x_train2 = x_train2.reset_index()
x_train3 = x_train3.reset_index()
x_test1 = x_test1.reset_index()
x_test2 = x_test2.reset_index()
x_test3 = x_test3.reset_index()

# %%
df_all['cluster_prediction'] = pp.kmeans_label(KMeans(), {'n_clusters':2}, df_all[features])
x_train1['cluster_prediction'] = pp.kmeans_label(KMeans(), {'n_clusters':2}, x_train1[features])
x_train2['cluster_prediction'] = pp.kmeans_label(KMeans(), {'n_clusters':2}, x_train2[features])
x_train3['cluster_prediction'] = pp.kmeans_label(KMeans(), {'n_clusters':2}, x_train3[features])
x_test1['cluster_prediction'] = pp.kmeans_label(KMeans(), {'n_clusters':2}, x_test1[features])
x_test2['cluster_prediction'] = pp.kmeans_label(KMeans(), {'n_clusters':2}, x_test2[features])
x_test3['cluster_prediction'] = pp.kmeans_label(KMeans(), {'n_clusters':2}, x_test3[features])

# %% [markdown]
# ## Summary statistics for each cluster

# %% [markdown]
# ### Identify the number of data points in each cluster

# %%
pp.cluster_size(df_all, 'cluster_prediction')
# Out:
# cluster_prediction
# 0    68910
# 1    56066
# Name: cluster_prediction, dtype: int64

# %%
pp.precision_at_threshold(df_all['label'], df_all['cluster_prediction'])
# Out:
# 0.30740555773552597

# %%
# test set 1
pp.cluster_size(x_test1, 'cluster_prediction')
# Out:
# cluster_prediction
# 0    18104
# 1    14856
# Name: cluster_prediction, dtype: int64

# %%
pp.precision_at_threshold(y_test1, x_test1['cluster_prediction'])
# Out:
# 0.27187668282175553

# %%
# test set 2
pp.cluster_size(x_test2, 'cluster_prediction')
# Out:
# cluster_prediction
# 0     9530
# 1    12177
# Name: cluster_prediction, dtype: int64

# %%
pp.precision_at_threshold(y_test2, x_test2['cluster_prediction'])
# Out:
# 0.3004023979633736

# %%
# final test set
pp.cluster_size(x_test3, 'cluster_prediction')
# Out:
# cluster_prediction
# 0    19613
# 1    24554
# Name: cluster_prediction, dtype: int64

# %%
pp.precision_at_threshold(y_test3, x_test3['cluster_prediction'])
# Out:
# 0.26875458173820965

# %% [markdown]
# ### Summarize features in each cluster

# %%
pp.summarize_kmeans_features(x_test1, 'cluster_prediction')
# Out:
# cluster_prediction                                                    0  \
# index                                       mean     62410.540653999116
# school_ncesid                               mean     249526295595.02765
# school_latitude                             mean      36.96648473547292
# school_longitude                            mean     -96.80654093874246
# total_price_including_optional_support      mean   0.005751896680662576
# students_reached                            mean   0.010230445837090334
# label                                       mean     0.2446420680512594
# school_metro_rural                          mean    0.11815068493150685
# school_metro_suburban                       mean     0.2702165267344233
# school_metro_urban                          mean     0.6116327883340699
# school_charter_f                            mean     0.9019553689792311
# school_charter_t                            mean     0.0980446310207689
# primary_focus_subject_Applied Sciences      mean    0.08274414494034467
# primary_focus_subject_Character Education   mean    0.03513035793194874
# primary_focus_subject_Civics & Government   mean    0.00585505965532479
# primary_focus_subject_College & Career Prep mean   0.015797613787008394
# primary_focus_subject_Community Service     mean   0.003314184710561202
# primary_focus_subject_ESL                   mean                    0.0
# primary_focus_subject_Early Development     mean   0.041261599646486964
# primary_focus_subject_Economics             mean   0.007788334069818824
# primary_focus_subject_Environmental Science mean    0.07081307998232435
# primary_focus_subject_Extracurricular       mean    0.00635218736190897
# primary_focus_subject_Foreign Languages     mean                    0.0
# primary_focus_subject_Gym & Fitness         mean    0.02104507291206363
# primary_focus_subject_Health & Life Science mean    0.06473707467962882
# primary_focus_subject_Health & Wellness     mean   0.015852850198851083
# primary_focus_subject_History & Geography   mean   0.037781705700397704
# primary_focus_subject_Literacy              mean                    0.0
# primary_focus_subject_Literature & Writing  mean                    0.0
# primary_focus_subject_Mathematics           mean    0.24408970393283252
# primary_focus_subject_Music                 mean    0.06048387096774194
# primary_focus_subject_Nutrition             mean   0.002596111356606275
# primary_focus_subject_Other                 mean   0.025353513035793196
# primary_focus_subject_Parent Involvement    mean  0.0019332744144940344
# primary_focus_subject_Performing Arts       mean   0.023365002209456472
# primary_focus_subject_Social Sciences       mean   0.021210782147591693
# primary_focus_subject_Special Needs         mean     0.1183163941670349
# primary_focus_subject_Sports                mean   0.007346442775077331
# primary_focus_subject_Visual Arts           mean     0.0868316394167035
# primary_focus_area_Applied Learning         mean     0.1291427308882015
# primary_focus_area_Health & Sports          mean    0.04684047724259832
# primary_focus_area_History & Civics         mean    0.07263588157313301
# primary_focus_area_Literacy & Language      mean                      0
# primary_focus_area_Math & Science           mean     0.4623840035351304
# primary_focus_area_Music & The Arts         mean     0.1706805125939019
# primary_focus_area_Special Needs            mean     0.1183163941670349
# grade_level_Grades 3-5                      mean    0.30832965090587716
# grade_level_Grades 6-8                      mean    0.20984312859036677
# grade_level_Grades 9-12                     mean     0.1760384445426425
# grade_level_Grades PreK-2                   mean     0.3057887759611136
# resource_type_Books                         mean    0.07202828104286346
# resource_type_Other                         mean    0.12505523641184269
# resource_type_Supplies                      mean    0.44001325673884223
# resource_type_Technology                    mean     0.3516902342023862
# resource_type_Trips                         mean   0.008893062306672559
# resource_type_Visitors                      mean  0.0023199292973928413
#
# cluster_prediction                                                    1
# index                                       mean     62692.114095315024
# school_ncesid                               mean     261815742509.61038
# school_latitude                             mean      37.12661719520725
# school_longitude                            mean     -94.32292013099082
# total_price_including_optional_support      mean  0.0045342486910804084
# students_reached                            mean    0.00546077461402503
# label                                       mean    0.27187668282175553
# school_metro_rural                          mean    0.10756596661281637
# school_metro_suburban                       mean    0.25854873451803984
# school_metro_urban                          mean     0.6338852988691438
# school_charter_f                            mean     0.8984921917070544
# school_charter_t                            mean    0.10150780829294562
# primary_focus_subject_Applied Sciences      mean                    0.0
# primary_focus_subject_Character Education   mean                    0.0
# primary_focus_subject_Civics & Government   mean                    0.0
# primary_focus_subject_College & Career Prep mean                    0.0
# primary_focus_subject_Community Service     mean                    0.0
# primary_focus_subject_ESL                   mean    0.02988691437802908
# primary_focus_subject_Early Development     mean                    0.0
# primary_focus_subject_Economics             mean                    0.0
# primary_focus_subject_Environmental Science mean                    0.0
# primary_focus_subject_Extracurricular       mean                    0.0
# primary_focus_subject_Foreign Languages     mean    0.01810716208939149
# primary_focus_subject_Gym & Fitness         mean                    0.0
# primary_focus_subject_Health & Life Science mean                    0.0
# primary_focus_subject_Health & Wellness     mean                    0.0
# primary_focus_subject_History & Geography   mean                    0.0
# primary_focus_subject_Literacy              mean     0.6645799676898223
# primary_focus_subject_Literature & Writing  mean    0.28742595584275715
# primary_focus_subject_Mathematics           mean                    0.0
# primary_focus_subject_Music                 mean                    0.0
# primary_focus_subject_Nutrition             mean                    0.0
# primary_focus_subject_Other                 mean                    0.0
# primary_focus_subject_Parent Involvement    mean                    0.0
# primary_focus_subject_Performing Arts       mean                    0.0
# primary_focus_subject_Social Sciences       mean                    0.0
# primary_focus_subject_Special Needs         mean                    0.0
# primary_focus_subject_Sports                mean                    0.0
# primary_focus_subject_Visual Arts           mean                    0.0
# primary_focus_area_Applied Learning         mean                    0.0
# primary_focus_area_Health & Sports          mean                    0.0
# primary_focus_area_History & Civics         mean                    0.0
# primary_focus_area_Literacy & Language      mean                      1
# primary_focus_area_Math & Science           mean                    0.0
# primary_focus_area_Music & The Arts         mean                    0.0
# primary_focus_area_Special Needs            mean                    0.0
# grade_level_Grades 3-5                      mean     0.3189956919763059
# grade_level_Grades 6-8                      mean     0.1377221324717286
# grade_level_Grades 9-12                     mean    0.08892030156165859
# grade_level_Grades PreK-2                   mean     0.4543618739903069
# resource_type_Books                         mean     0.3568928379106085
# resource_type_Other                         mean    0.10083467959073775
# resource_type_Supplies                      mean    0.20254442649434573
# resource_type_Technology                    mean     0.3381125471190092
# resource_type_Trips                         mean   0.000942380183091007
# resource_type_Visitors                      mean  0.0006731287022078621

# %%
pp.summarize_kmeans_features(x_test2, 'cluster_prediction')
# Out:
# cluster_prediction                                                    0  \
# index                                       mean     62808.601573976914
# school_ncesid                               mean      253602826011.5444
# school_latitude                             mean      37.32167131269662
# school_longitude                            mean     -92.17350570881413
# total_price_including_optional_support      mean   0.010787932394781735
# students_reached                            mean    0.06414516246768633
# label                                       mean    0.33567681007345224
# school_metro_rural                          mean    0.12497376705141658
# school_metro_suburban                       mean    0.27051416579223503
# school_metro_urban                          mean     0.6045120671563484
# school_charter_f                            mean     0.9061909758656873
# school_charter_t                            mean    0.09380902413431269
# primary_focus_subject_Applied Sciences      mean                    0.0
# primary_focus_subject_Character Education   mean                    0.0
# primary_focus_subject_Civics & Government   mean                    0.0
# primary_focus_subject_College & Career Prep mean                    0.0
# primary_focus_subject_Community Service     mean                    0.0
# primary_focus_subject_ESL                   mean   0.028541448058761805
# primary_focus_subject_Early Development     mean                    0.0
# primary_focus_subject_Economics             mean                    0.0
# primary_focus_subject_Environmental Science mean                    0.0
# primary_focus_subject_Extracurricular       mean                    0.0
# primary_focus_subject_Foreign Languages     mean   0.017418677859391395
# primary_focus_subject_Gym & Fitness         mean                    0.0
# primary_focus_subject_Health & Life Science mean                    0.0
# primary_focus_subject_Health & Wellness     mean                    0.0
# primary_focus_subject_History & Geography   mean                    0.0
# primary_focus_subject_Literacy              mean     0.6718782791185729
# primary_focus_subject_Literature & Writing  mean    0.28216159496327387
# primary_focus_subject_Mathematics           mean                    0.0
# primary_focus_subject_Music                 mean                    0.0
# primary_focus_subject_Nutrition             mean                    0.0
# primary_focus_subject_Other                 mean                    0.0
# primary_focus_subject_Parent Involvement    mean                    0.0
# primary_focus_subject_Performing Arts       mean                    0.0
# primary_focus_subject_Social Sciences       mean                    0.0
# primary_focus_subject_Special Needs         mean                    0.0
# primary_focus_subject_Sports                mean                    0.0
# primary_focus_subject_Visual Arts           mean                    0.0
# primary_focus_area_Applied Learning         mean                    0.0
# primary_focus_area_Health & Sports          mean                    0.0
# primary_focus_area_History & Civics         mean                    0.0
# primary_focus_area_Literacy & Language      mean                      1
# primary_focus_area_Math & Science           mean                    0.0
# primary_focus_area_Music & The Arts         mean                    0.0
# primary_focus_area_Special Needs            mean                    0.0
# grade_level_Grades 3-5                      mean    0.30220356768100737
# grade_level_Grades 6-8                      mean     0.1286463798530955
# grade_level_Grades 9-12                     mean      0.080797481636936
# grade_level_Grades PreK-2                   mean    0.48835257082896116
# resource_type_Books                         mean    0.34512067156348375
# resource_type_Other                         mean    0.09150052465897167
# resource_type_Supplies                      mean    0.21846799580272822
# resource_type_Technology                    mean      0.342707240293809
# resource_type_Trips                         mean  0.0015739769150052466
# resource_type_Visitors                      mean  0.0006295907660020986
#
# cluster_prediction                                                    1
# index                                       mean      61888.73638827298
# school_ncesid                               mean     244308549066.08783
# school_latitude                             mean      37.20553861304127
# school_longitude                            mean     -94.18459002217345
# total_price_including_optional_support      mean   0.013340851920420428
# students_reached                            mean    0.11155586963807676
# label                                       mean     0.3004023979633736
# school_metro_rural                          mean    0.13131313131313133
# school_metro_suburban                       mean    0.25671347622567137
# school_metro_urban                          mean     0.6119733924611973
# school_charter_f                            mean      0.906216637923955
# school_charter_t                            mean      0.093783362076045
# primary_focus_subject_Applied Sciences      mean    0.07653773507432043
# primary_focus_subject_Character Education   mean    0.02340477950234048
# primary_focus_subject_Civics & Government   mean   0.007144616900714462
# primary_focus_subject_College & Career Prep mean   0.015192576168185925
# primary_focus_subject_Community Service     mean  0.0032848813336618216
# primary_focus_subject_ESL                   mean                    0.0
# primary_focus_subject_Early Development     mean   0.037611891270427855
# primary_focus_subject_Economics             mean    0.01084010840108401
# primary_focus_subject_Environmental Science mean     0.0716104130738277
# primary_focus_subject_Extracurricular       mean   0.006323396567299007
# primary_focus_subject_Foreign Languages     mean                    0.0
# primary_focus_subject_Gym & Fitness         mean     0.0174919931017492
# primary_focus_subject_Health & Life Science mean   0.057156935205715693
# primary_focus_subject_Health & Wellness     mean   0.025539952369220662
# primary_focus_subject_History & Geography   mean    0.03991130820399113
# primary_focus_subject_Literacy              mean                    0.0
# primary_focus_subject_Literature & Writing  mean                    0.0
# primary_focus_subject_Mathematics           mean     0.2471051983247105
# primary_focus_subject_Music                 mean   0.056746325039007964
# primary_focus_subject_Nutrition             mean   0.003941857600394186
# primary_focus_subject_Other                 mean   0.028578467602857847
# primary_focus_subject_Parent Involvement    mean  0.0016424406668309108
# primary_focus_subject_Performing Arts       mean   0.021926582902192657
# primary_focus_subject_Social Sciences       mean     0.0211053625687772
# primary_focus_subject_Special Needs         mean    0.12917795844625113
# primary_focus_subject_Sports                mean   0.009444033834277736
# primary_focus_subject_Visual Arts           mean    0.08828118584216145
# primary_focus_area_Applied Learning         mean    0.11603843311160385
# primary_focus_area_Health & Sports          mean    0.05641783690564178
# primary_focus_area_History & Civics         mean    0.07900139607456681
# primary_focus_area_Literacy & Language      mean                      0
# primary_focus_area_Math & Science           mean     0.4524102816785744
# primary_focus_area_Music & The Arts         mean    0.16695409378336207
# primary_focus_area_Special Needs            mean    0.12917795844625113
# grade_level_Grades 3-5                      mean     0.3202759300320276
# grade_level_Grades 6-8                      mean    0.19561468341956148
# grade_level_Grades 9-12                     mean    0.15775642604910897
# grade_level_Grades PreK-2                   mean    0.32635296049930196
# resource_type_Books                         mean    0.06315184363964851
# resource_type_Other                         mean    0.11948755851194875
# resource_type_Supplies                      mean    0.44838630204483865
# resource_type_Technology                    mean     0.3576414552024308
# resource_type_Trips                         mean   0.009690399934302374
# resource_type_Visitors                      mean  0.0016424406668309108

# %%
pp.summarize_kmeans_features(x_test3, 'cluster_prediction')
# Out:
# cluster_prediction                                                    0  \
# index                                       mean      62633.34732065467
# school_ncesid                               mean     260545570712.56766
# school_latitude                             mean         36.61483417106
# school_longitude                            mean     -94.12002617019314
# total_price_including_optional_support      mean  0.0031388639715564833
# students_reached                            mean    0.06385232607671905
# label                                       mean     0.3045429052159282
# school_metro_rural                          mean    0.11058991485239382
# school_metro_suburban                       mean     0.2816499260694437
# school_metro_urban                          mean     0.6077601590781625
# school_charter_f                            mean     0.9035333707234997
# school_charter_t                            mean    0.09646662927650028
# primary_focus_subject_Applied Sciences      mean                    0.0
# primary_focus_subject_Character Education   mean                    0.0
# primary_focus_subject_Civics & Government   mean                    0.0
# primary_focus_subject_College & Career Prep mean                    0.0
# primary_focus_subject_Community Service     mean                    0.0
# primary_focus_subject_ESL                   mean    0.02829755774231377
# primary_focus_subject_Early Development     mean                    0.0
# primary_focus_subject_Economics             mean                    0.0
# primary_focus_subject_Environmental Science mean                    0.0
# primary_focus_subject_Extracurricular       mean                    0.0
# primary_focus_subject_Foreign Languages     mean    0.01646866874012135
# primary_focus_subject_Gym & Fitness         mean                    0.0
# primary_focus_subject_Health & Life Science mean                    0.0
# primary_focus_subject_Health & Wellness     mean                    0.0
# primary_focus_subject_History & Geography   mean                    0.0
# primary_focus_subject_Literacy              mean     0.6671085504512313
# primary_focus_subject_Literature & Writing  mean    0.28812522306633354
# primary_focus_subject_Mathematics           mean                    0.0
# primary_focus_subject_Music                 mean                    0.0
# primary_focus_subject_Nutrition             mean                    0.0
# primary_focus_subject_Other                 mean                    0.0
# primary_focus_subject_Parent Involvement    mean                    0.0
# primary_focus_subject_Performing Arts       mean                    0.0
# primary_focus_subject_Social Sciences       mean                    0.0
# primary_focus_subject_Special Needs         mean                    0.0
# primary_focus_subject_Sports                mean                    0.0
# primary_focus_subject_Visual Arts           mean                    0.0
# primary_focus_area_Applied Learning         mean                    0.0
# primary_focus_area_Health & Sports          mean                    0.0
# primary_focus_area_History & Civics         mean                    0.0
# primary_focus_area_Literacy & Language      mean                      1
# primary_focus_area_Math & Science           mean                    0.0
# primary_focus_area_Music & The Arts         mean                    0.0
# primary_focus_area_Special Needs            mean                    0.0
# grade_level_Grades 3-5                      mean     0.3205526946413093
# grade_level_Grades 6-8                      mean     0.1262427981440881
# grade_level_Grades 9-12                     mean    0.07902921531637179
# grade_level_Grades PreK-2                   mean    0.47417529189823077
# resource_type_Books                         mean    0.33487992657930965
# resource_type_Other                         mean    0.09804721358282771
# resource_type_Supplies                      mean    0.19262733900984041
# resource_type_Technology                    mean    0.37296690970274815
# resource_type_Trips                         mean  0.0009177586294804467
# resource_type_Visitors                      mean  0.0005608524957936063
#
# cluster_prediction                                                    1
# index                                       mean      62539.18831962206
# school_ncesid                               mean     247766270121.90298
# school_latitude                             mean      36.52179502753128
# school_longitude                            mean      -95.9845992475771
# total_price_including_optional_support      mean   0.004307736883367864
# students_reached                            mean     0.1241334587395884
# label                                       mean    0.26875458173820965
# school_metro_rural                          mean    0.11717031848171378
# school_metro_suburban                       mean    0.28985094078357904
# school_metro_urban                          mean     0.5929787407347071
# school_charter_f                            mean     0.9080801498737476
# school_charter_t                            mean    0.09191985012625234
# primary_focus_subject_Applied Sciences      mean    0.09843610002443594
# primary_focus_subject_Character Education   mean   0.016494257554777226
# primary_focus_subject_Civics & Government   mean   0.004846460861774049
# primary_focus_subject_College & Career Prep mean   0.021299991854687627
# primary_focus_subject_Community Service     mean   0.002932312454182618
# primary_focus_subject_ESL                   mean                    0.0
# primary_focus_subject_Early Development     mean   0.037101897857782846
# primary_focus_subject_Economics             mean  0.0053351796041378186
# primary_focus_subject_Environmental Science mean    0.07004968640547365
# primary_focus_subject_Extracurricular       mean  0.0074122342591838395
# primary_focus_subject_Foreign Languages     mean                    0.0
# primary_focus_subject_Gym & Fitness         mean    0.01596481225054981
# primary_focus_subject_Health & Life Science mean    0.05685428036165187
# primary_focus_subject_Health & Wellness     mean    0.02109635904536939
# primary_focus_subject_History & Geography   mean   0.036694632239146374
# primary_focus_subject_Literacy              mean                    0.0
# primary_focus_subject_Literature & Writing  mean                    0.0
# primary_focus_subject_Mathematics           mean     0.2632157693247536
# primary_focus_subject_Music                 mean    0.05510303820151503
# primary_focus_subject_Nutrition             mean   0.002443593711818848
# primary_focus_subject_Other                 mean   0.025209741793597785
# primary_focus_subject_Parent Involvement    mean   0.001547609350818604
# primary_focus_subject_Performing Arts       mean    0.02577991365968885
# primary_focus_subject_Social Sciences       mean   0.021666530911460456
# primary_focus_subject_Special Needs         mean    0.12046916999266923
# primary_focus_subject_Sports                mean   0.007738046754093019
# primary_focus_subject_Visual Arts           mean    0.08230838152643154
# primary_focus_area_Applied Learning         mean    0.11199804512503055
# primary_focus_area_Health & Sports          mean   0.047242811761831066
# primary_focus_area_History & Civics         mean     0.0685428036165187
# primary_focus_area_Literacy & Language      mean                      0
# primary_focus_area_Math & Science           mean    0.48855583611631503
# primary_focus_area_Music & The Arts         mean    0.16319133338763542
# primary_focus_area_Special Needs            mean    0.12046916999266923
# grade_level_Grades 3-5                      mean     0.3158752138144498
# grade_level_Grades 6-8                      mean    0.21075995764437566
# grade_level_Grades 9-12                     mean    0.17854524721023052
# grade_level_Grades PreK-2                   mean    0.29481958133094405
# resource_type_Books                         mean    0.06740245988433656
# resource_type_Other                         mean    0.12246477152398795
# resource_type_Supplies                      mean    0.38816486112242404
# resource_type_Technology                    mean    0.41565529038038607
# resource_type_Trips                         mean   0.004887187423637696
# resource_type_Visitors                      mean  0.0014254296652276616

# %%
pp.plot_2d_cluster(x_test3, 'cluster_prediction','students_reached', 'total_price_including_optional_support')

# %% [markdown]
# ### Identify "distinctive" features of clusters

# %%
# fit classifier
features.append('primary_focus_area_LiteracyLanguage')
dt_1 = DecisionTreeClassifier(max_depth = 5)
dt_1.fit(x_test3[features], x_test3['cluster_prediction'])
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
# graph tree
pp.graph_tree(dt_1, features, 'tree3.png')

# %%
# show image
Image('tree3.png')

# %% [markdown]
# ### Now look at distinguishing features when removing 'primary_focus_area_LiteracyLanguage'

# %%
features.remove('primary_focus_area_LiteracyLanguage')
dt_2 = DecisionTreeClassifier(max_depth = 5)
dt_2.fit(x_test3[features], x_test3['cluster_prediction'])
pp.graph_tree(dt_2, features, 'tree3_2.png')
Image('tree3_2.png')

# %% [markdown]
# # Further analysis

# %% [markdown]
# ## Merge clusters into one

# %%
# create fake dataset to run these on 
df_final = x_test1.copy()

# %%
z=pp.merge_clusters(df_final, 'cluster_prediction', [0,1],1)

# %%
z['cluster_prediction'].unique()
# Out:
# array([1])

# %% [markdown]
# ## Recluster with a new k

# %%
df_final['cluster_prediction'] = pp.kmeans_label(KMeans(), {'n_clusters':3}, df_final[features])

# %%
df_final['cluster_prediction'].unique()
# Out:
# array([0, 1, 2])

# %% [markdown]
# ## Split a specific cluster into many (with a specific number of new clustering)

# %%
df_final =pp.split_cluster(df_final, 'cluster_prediction', features,2, {'n_clusters':3},[2,3,4])

# %%
df_final['cluster_prediction'].unique()
# Out:
# array([0., 1., 2., 3., 4.])

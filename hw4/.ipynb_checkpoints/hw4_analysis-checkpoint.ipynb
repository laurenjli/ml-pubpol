# %% [markdown]
# # Assignment 4

# %%
import ml_pipeline as pp
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from sklearn.tree import DecisionTreeClassifier
from IPython.display import Image
import datetime as dt

# %% [markdown]
# ## Load data

# %%
filename = './data/projects_2012_2013.csv'
df = pp.load_csv(filename)

# %% [markdown]
# ## Process data for clustering

# %% [markdown]
# ### Missing values

# %%
df.columns
# Out:
# Index(['projectid', 'teacher_acctid', 'schoolid', 'school_ncesid',
#        'school_latitude', 'school_longitude', 'school_city', 'school_state',
#        'school_metro', 'school_district', 'school_county', 'school_charter',
#        'school_magnet', 'teacher_prefix', 'primary_focus_subject',
#        'primary_focus_area', 'secondary_focus_subject', 'secondary_focus_area',
#        'resource_type', 'poverty_level', 'grade_level',
#        'total_price_including_optional_support', 'students_reached',
#        'eligible_double_your_impact_match', 'date_posted', 'datefullyfunded'],
#       dtype='object')

# %%
pp.na_col(df)
# Out:
# ['school_ncesid',
#  'school_metro',
#  'school_district',
#  'primary_focus_subject',
#  'primary_focus_area',
#  'secondary_focus_subject',
#  'secondary_focus_area',
#  'resource_type',
#  'grade_level',
#  'students_reached']

# %%
cat_col = ['school_metro',
 'school_district',
 'primary_focus_subject',
 'primary_focus_area',
 'secondary_focus_subject',
 'secondary_focus_area',
 'resource_type',
 'grade_level']
for c in cat_col:
    df_all = pp.na_fill_col(df, c, pp.most_freq)

# %%
df_all = pp.na_fill_col(df, 'students_reached', np.nanmean)

# %% [markdown]
# ### Categorical variables to binary

# %%
df_all = pp.feat_binary(df, ['school_city','school_state','school_metro','school_charter','primary_focus_subject','primary_focus_area', 'grade_level', 'resource_type'])

# %% [markdown]
# ### Normalization

# %%
num_col = ['total_price_including_optional_support', 'students_reached']

# %%
pp.normalize_mult_minmax(df_all, num_col)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %% [markdown]
# ### Given a k, generate k clusters using KMeans

# %%
cat_feat = ['school_metro_rural',
 'school_metro_suburban',
 'school_metro_urban',
 'school_charter_f',
 'school_charter_t',
 'primary_focus_subject_Applied Sciences',
 'primary_focus_subject_Character Education',
 'primary_focus_subject_Civics & Government',
 'primary_focus_subject_College & Career Prep',
 'primary_focus_subject_Community Service',
 'primary_focus_subject_ESL',
 'primary_focus_subject_Early Development',
 'primary_focus_subject_Economics',
 'primary_focus_subject_Environmental Science',
 'primary_focus_subject_Extracurricular',
 'primary_focus_subject_Foreign Languages',
 'primary_focus_subject_Gym & Fitness',
 'primary_focus_subject_Health & Life Science',
 'primary_focus_subject_Health & Wellness',
 'primary_focus_subject_History & Geography',
 'primary_focus_subject_Literacy',
 'primary_focus_subject_Literature & Writing',
 'primary_focus_subject_Mathematics',
 'primary_focus_subject_Music',
 'primary_focus_subject_Nutrition',
 'primary_focus_subject_Other',
 'primary_focus_subject_Parent Involvement',
 'primary_focus_subject_Performing Arts',
 'primary_focus_subject_Social Sciences',
 'primary_focus_subject_Special Needs',
 'primary_focus_subject_Sports',
 'primary_focus_subject_Visual Arts',
 'primary_focus_area_Applied Learning',
 'primary_focus_area_Health & Sports',
 'primary_focus_area_History & Civics',
 'primary_focus_area_Literacy & Language',
 'primary_focus_area_Math & Science',
 'primary_focus_area_Music & The Arts',
 'primary_focus_area_Special Needs',
 'grade_level_Grades 3-5',
 'grade_level_Grades 6-8',
 'grade_level_Grades 9-12',
 'grade_level_Grades PreK-2',
 'resource_type_Books',
 'resource_type_Other',
 'resource_type_Supplies',
 'resource_type_Technology',
 'resource_type_Trips',
 'resource_type_Visitors']
num_feat = ['total_price_including_optional_support', 'students_reached']
features = cat_feat + num_feat

# %%
# rename columns so they can shown by export_graphviz
for c in df_all.columns:
    if '&' in c:
        new = c.replace(' & ', '')
        df_all = df_all.rename(columns = {c:new})
        features.remove(c)
        features.append(new)

# %%
df_all['cluster_prediction'] = pp.kmeans_label(KMeans(), {'n_clusters':2}, df_all[features])

# %% [markdown]
# ## Summary statistics for each cluster

# %% [markdown]
# ### Identify the number of data points in each cluster

# %%
pp.cluster_size(df_all, 'cluster_prediction')
# Out:
# cluster_prediction
# 0    56066
# 1    68910
# Name: cluster_prediction, dtype: int64

# %% [markdown]
# ### Summarize features in each cluster

# %%
pp.summarize_kmeans_features(df_all, 'cluster_prediction')
# Out:
# cluster_prediction                                                    0  \
# school_ncesid                               mean     249454408156.13455
# school_latitude                             mean      36.87152599192029
# school_longitude                            mean     -94.97633523199447
# total_price_including_optional_support      mean   0.002955617560942986
# students_reached                            mean  0.0052326978559264865
# school_metro_rural                          mean    0.11035208504262833
# school_metro_suburban                       mean     0.2625298755038704
# school_metro_urban                          mean     0.6271180394535012
# school_charter_f                            mean     0.9047372739271573
# school_charter_t                            mean    0.09526272607284272
# primary_focus_subject_Applied Sciences      mean                    0.0
# primary_focus_subject_Character Education   mean                    0.0
# primary_focus_subject_CivicsGovernment      mean                    0.0
# primary_focus_subject_CollegeCareer Prep    mean                    0.0
# primary_focus_subject_Community Service     mean                    0.0
# primary_focus_subject_ESL                   mean     0.0286091392287661
# primary_focus_subject_Early Development     mean                    0.0
# primary_focus_subject_Economics             mean                    0.0
# primary_focus_subject_Environmental Science mean                    0.0
# primary_focus_subject_Extracurricular       mean                    0.0
# primary_focus_subject_Foreign Languages     mean    0.01601683729889773
# primary_focus_subject_GymFitness            mean                    0.0
# primary_focus_subject_HealthLife Science    mean                    0.0
# primary_focus_subject_HealthWellness        mean                    0.0
# primary_focus_subject_HistoryGeography      mean                    0.0
# primary_focus_subject_Literacy              mean     0.6674811828915921
# primary_focus_subject_LiteratureWriting     mean     0.2878928405807441
# primary_focus_subject_Mathematics           mean                    0.0
# primary_focus_subject_Music                 mean                    0.0
# primary_focus_subject_Nutrition             mean                    0.0
# primary_focus_subject_Other                 mean                    0.0
# primary_focus_subject_Parent Involvement    mean                    0.0
# primary_focus_subject_Performing Arts       mean                    0.0
# primary_focus_subject_Social Sciences       mean                    0.0
# primary_focus_subject_Special Needs         mean                    0.0
# primary_focus_subject_Sports                mean                    0.0
# primary_focus_subject_Visual Arts           mean                    0.0
# primary_focus_area_Applied Learning         mean                    0.0
# primary_focus_area_HealthSports             mean                    0.0
# primary_focus_area_HistoryCivics            mean                    0.0
# primary_focus_area_LiteracyLanguage         mean                      1
# primary_focus_area_MathScience              mean                    0.0
# primary_focus_area_MusicThe Arts            mean                    0.0
# primary_focus_area_Special Needs            mean                    0.0
# grade_level_Grades 3-5                      mean     0.3157171904541077
# grade_level_Grades 6-8                      mean    0.13025719687511148
# grade_level_Grades 9-12                     mean    0.08224235722184568
# grade_level_Grades PreK-2                   mean     0.4717832554489352
# resource_type_Books                         mean    0.34297078443263296
# resource_type_Other                         mean    0.09506652873399209
# resource_type_Supplies                      mean     0.2018335533121678
# resource_type_Technology                    mean     0.3583633574715514
# resource_type_Trips                         mean   0.001212856276531231
# resource_type_Visitors                      mean  0.0005529197731245318
#
# cluster_prediction                                                    1
# school_ncesid                               mean      241081190704.2421
# school_latitude                             mean     36.791287451385664
# school_longitude                            mean     -96.57768940621045
# total_price_including_optional_support      mean   0.003799340983568518
# students_reached                            mean   0.009849677512182001
# school_metro_rural                          mean    0.11919895515890291
# school_metro_suburban                       mean     0.2665070381657234
# school_metro_urban                          mean     0.6142940066753737
# school_charter_f                            mean     0.9086489624147439
# school_charter_t                            mean    0.09135103758525613
# primary_focus_subject_Applied Sciences      mean    0.08453054709040778
# primary_focus_subject_Character Education   mean   0.032636772601944565
# primary_focus_subject_CivicsGovernment      mean   0.006210999854883181
# primary_focus_subject_CollegeCareer Prep    mean   0.017660716877086053
# primary_focus_subject_Community Service     mean   0.003207081700769119
# primary_focus_subject_ESL                   mean                    0.0
# primary_focus_subject_Early Development     mean   0.037991583224495716
# primary_focus_subject_Economics             mean  0.0071252358148309386
# primary_focus_subject_Environmental Science mean    0.07016398200551444
# primary_focus_subject_Extracurricular       mean   0.006965607313887679
# primary_focus_subject_Foreign Languages     mean                    0.0
# primary_focus_subject_GymFitness            mean   0.018589464518937743
# primary_focus_subject_HealthLife Science    mean    0.06073138876795821
# primary_focus_subject_HealthWellness        mean   0.021041938760702365
# primary_focus_subject_HistoryGeography      mean    0.03919605282252213
# primary_focus_subject_Literacy              mean                    0.0
# primary_focus_subject_LiteratureWriting     mean                    0.0
# primary_focus_subject_Mathematics           mean    0.24465244521840082
# primary_focus_subject_Music                 mean    0.05704542156435931
# primary_focus_subject_Nutrition             mean  0.0027572195617472065
# primary_focus_subject_Other                 mean   0.026251632564214193
# primary_focus_subject_Parent Involvement    mean  0.0018574952837033811
# primary_focus_subject_Performing Arts       mean   0.024408648962414743
# primary_focus_subject_Social Sciences       mean    0.02231896676824844
# primary_focus_subject_Special Needs         mean     0.1211435205340299
# primary_focus_subject_Sports                mean    0.00832970541285735
# primary_focus_subject_Visual Arts           mean    0.08518357277608475
# primary_focus_area_Applied Learning         mean     0.1265708895661007
# primary_focus_area_HealthSports             mean    0.05071832825424467
# primary_focus_area_HistoryCivics            mean     0.0748512552604847
# primary_focus_area_LiteracyLanguage         mean                      0
# primary_focus_area_MathScience              mean     0.4600783630822812
# primary_focus_area_MusicThe Arts            mean     0.1666376433028588
# primary_focus_area_Special Needs            mean     0.1211435205340299
# grade_level_Grades 3-5                      mean    0.31259613989261353
# grade_level_Grades 6-8                      mean    0.20571760267014946
# grade_level_Grades 9-12                     mean    0.17284864315774198
# grade_level_Grades PreK-2                   mean      0.308837614279495
# resource_type_Books                         mean    0.07251487447395154
# resource_type_Other                         mean    0.12192715135684226
# resource_type_Supplies                      mean     0.4201712378464664
# resource_type_Technology                    mean      0.374561021622406
# resource_type_Trips                         mean    0.00920040632709331
# resource_type_Visitors                      mean  0.0016253083732404585

# %%
pp.plot_2d_cluster(df_all, 'cluster_prediction','students_reached', 'total_price_including_optional_support')

# %% [markdown]
# ### Identify "distinctive" features of clusters

# %%
# fit classifier
#features.append('primary_focus_area_LiteracyLanguage')
dt_1 = DecisionTreeClassifier(max_depth = 5)
dt_1.fit(df_all[features], df_all['cluster_prediction'])
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
# graph tree
pp.graph_tree(dt_1, features, 'treeall.png')

# %%
# show image
Image('treeall.png')

# %% [markdown]
# ### Now look at distinguishing features when removing 'primary_focus_area_LiteracyLanguage'

# %%
#features.remove('primary_focus_area_LiteracyLanguage')
dt_2 = DecisionTreeClassifier(max_depth = 5)
dt_2.fit(df_all[features], df_all['cluster_prediction'])
pp.graph_tree(dt_2, features, 'treeall2.png')
Image('treeall2.png')

# %% [markdown]
# # Further analysis

# %% [markdown]
# ## Merge clusters into one

# %%
# create fake dataset to run these on 
df_final = x_test1.copy()

# %%
z=pp.merge_clusters(df_final, 'cluster_prediction', [0,1],1)

# %%
z['cluster_prediction'].unique()
# Out:
# array([1])

# %% [markdown]
# ## Recluster with a new k

# %%
df_final['cluster_prediction'] = pp.kmeans_label(KMeans(), {'n_clusters':3}, df_final[features])

# %%
df_final['cluster_prediction'].unique()
# Out:
# array([0, 1, 2])

# %% [markdown]
# ## Split a specific cluster into many (with a specific number of new clustering)

# %%
df_final =pp.split_cluster(df_final, 'cluster_prediction', features,2, {'n_clusters':3},[2,3,4])

# %%
df_final['cluster_prediction'].unique()
# Out:
# array([0., 1., 2., 3., 4.])

# %% [markdown]
# ## Clustering HW5 predictions

# %%
pred_hw5 = pp.load_csv('./data/hw5_top5.csv')

# %%
pred_hw5['cluster'] = pp.kmeans_label(KMeans(), {'n_clusters':4}, pred_hw5[features])

# %%
pred_hw5.cluster.unique()
# Out:
# array([0, 3, 2, 1])

# %%
focus = [x for x in pred_hw5.columns if 'primary_focus' in x]
focus.append('cluster')

# %%
pp.summarize_kmeans_features(pred_hw5, 'cluster')
# Out:
# cluster                                                                0  \
# index                                         mean    10135.940540540541
# school_city_Bakersfield                       mean                   0.0
# school_city_Baltimore                         mean                   0.0
# school_city_Bronx                             mean                   0.0
# school_city_Brooklyn                          mean                   0.0
# school_city_Charlotte                         mean                   0.0
# school_city_Chicago                           mean                   0.0
# school_city_Columbus                          mean                   0.0
# school_city_Dallas                            mean                   0.0
# school_city_Denver                            mean                     0
# school_city_Houston                           mean  0.005405405405405406
# school_city_Indianapolis                      mean                   0.0
# school_city_Las Vegas                         mean   0.03783783783783784
# school_city_Los Angeles                       mean  0.016216216216216217
# school_city_Memphis                           mean                   0.0
# school_city_N Hollywood                       mean                   0.0
# school_city_New Orleans                       mean                   0.0
# school_city_New York                          mean                   0.0
# school_city_North Hills                       mean                     0
# school_city_Oakland                           mean                   0.0
# school_city_Other                             mean    0.9297297297297298
# school_city_Philadelphia                      mean                   0.0
# school_city_Phoenix                           mean                   0.0
# school_city_Portland                          mean                     0
# school_city_Richmond                          mean                   0.0
# school_city_Sacramento                        mean                     0
# school_city_San Francisco                     mean                     0
# school_city_Seattle                           mean  0.005405405405405406
# school_city_South Gate                        mean  0.005405405405405406
# school_city_Tulsa                             mean                   0.0
# ...                                                                  ...
# secondary_focus_area_Special Needs            mean  0.043243243243243246
# resource_type_Books                           mean   0.14054054054054055
# resource_type_Other                           mean   0.14054054054054055
# resource_type_Supplies                        mean   0.23243243243243245
# resource_type_Technology                      mean    0.4810810810810811
# resource_type_Trips                           mean                   0.0
# resource_type_Visitors                        mean  0.005405405405405406
# poverty_level_high poverty                    mean   0.24324324324324326
# poverty_level_highest poverty                 mean    0.4486486486486487
# poverty_level_low poverty                     mean   0.02702702702702703
# poverty_level_moderate poverty                mean    0.2810810810810811
# grade_level_Grades 3-5                        mean   0.32432432432432434
# grade_level_Grades 6-8                        mean   0.15675675675675677
# grade_level_Grades 9-12                       mean    0.0972972972972973
# grade_level_Grades PreK-2                     mean   0.42162162162162165
# total_price_including_optional_support_lowest mean   0.04864864864864865
# total_price_including_optional_support_low    mean                   0.2
# total_price_including_optional_support_medium mean    0.1837837837837838
# total_price_including_optional_support_high   mean    0.5675675675675675
# students_reached_lowest                       mean   0.31891891891891894
# students_reached_low                          mean   0.24324324324324326
# students_reached_medium                       mean    0.1783783783783784
# students_reached_high                         mean    0.2594594594594595
# eligible_double_your_impact_match_f           mean    0.9027027027027027
# eligible_double_your_impact_match_t           mean    0.0972972972972973
# label                                         mean    0.5351351351351351
# scores                                        mean                     1
# students_reached                              mean   0.08650273511351343
# total_price_including_optional_support        mean   0.01615373822702703
# pred                                          mean                     1
#
# cluster                                                                1  \
# index                                         mean    11986.758974358974
# school_city_Bakersfield                       mean                   0.0
# school_city_Baltimore                         mean  0.005128205128205128
# school_city_Bronx                             mean  0.015384615384615385
# school_city_Brooklyn                          mean  0.015384615384615385
# school_city_Charlotte                         mean                   0.0
# school_city_Chicago                           mean                   0.0
# school_city_Columbus                          mean                   0.0
# school_city_Dallas                            mean                   0.0
# school_city_Denver                            mean                     0
# school_city_Houston                           mean                   0.0
# school_city_Indianapolis                      mean  0.020512820512820513
# school_city_Las Vegas                         mean  0.010256410256410256
# school_city_Los Angeles                       mean    0.2564102564102564
# school_city_Memphis                           mean                   0.0
# school_city_N Hollywood                       mean                   0.0
# school_city_New Orleans                       mean                   0.0
# school_city_New York                          mean                   0.0
# school_city_North Hills                       mean                     0
# school_city_Oakland                           mean  0.005128205128205128
# school_city_Other                             mean    0.6256410256410256
# school_city_Philadelphia                      mean  0.010256410256410256
# school_city_Phoenix                           mean  0.005128205128205128
# school_city_Portland                          mean                     0
# school_city_Richmond                          mean  0.005128205128205128
# school_city_Sacramento                        mean                     0
# school_city_San Francisco                     mean                     0
# school_city_Seattle                           mean                   0.0
# school_city_South Gate                        mean                   0.0
# school_city_Tulsa                             mean  0.010256410256410256
# ...                                                                  ...
# secondary_focus_area_Special Needs            mean  0.015384615384615385
# resource_type_Books                           mean  0.010256410256410256
# resource_type_Other                           mean   0.05641025641025641
# resource_type_Supplies                        mean   0.15897435897435896
# resource_type_Technology                      mean     0.764102564102564
# resource_type_Trips                           mean  0.005128205128205128
# resource_type_Visitors                        mean  0.005128205128205128
# poverty_level_high poverty                    mean    0.3641025641025641
# poverty_level_highest poverty                 mean    0.5025641025641026
# poverty_level_low poverty                     mean  0.015384615384615385
# poverty_level_moderate poverty                mean   0.11794871794871795
# grade_level_Grades 3-5                        mean    0.4256410256410256
# grade_level_Grades 6-8                        mean   0.19487179487179487
# grade_level_Grades 9-12                       mean   0.10256410256410256
# grade_level_Grades PreK-2                     mean   0.27692307692307694
# total_price_including_optional_support_lowest mean  0.015384615384615385
# total_price_including_optional_support_low    mean   0.10256410256410256
# total_price_including_optional_support_medium mean   0.17435897435897435
# total_price_including_optional_support_high   mean    0.7076923076923077
# students_reached_lowest                       mean   0.08717948717948718
# students_reached_low                          mean   0.41025641025641024
# students_reached_medium                       mean    0.2717948717948718
# students_reached_high                         mean   0.23076923076923078
# eligible_double_your_impact_match_f           mean    0.9487179487179487
# eligible_double_your_impact_match_t           mean   0.05128205128205128
# label                                         mean    0.4564102564102564
# scores                                        mean                     1
# students_reached                              mean   0.07471352949743579
# total_price_including_optional_support        mean  0.020018264656410253
# pred                                          mean                     1
#
# cluster                                                                2  \
# index                                         mean    10492.712918660287
# school_city_Bakersfield                       mean                   0.0
# school_city_Baltimore                         mean                   0.0
# school_city_Bronx                             mean                   0.0
# school_city_Brooklyn                          mean                   0.0
# school_city_Charlotte                         mean  0.009569377990430622
# school_city_Chicago                           mean                   0.0
# school_city_Columbus                          mean                   0.0
# school_city_Dallas                            mean  0.004784688995215311
# school_city_Denver                            mean                     0
# school_city_Houston                           mean                   0.0
# school_city_Indianapolis                      mean                   0.0
# school_city_Las Vegas                         mean  0.004784688995215311
# school_city_Los Angeles                       mean                   0.0
# school_city_Memphis                           mean                   0.0
# school_city_N Hollywood                       mean                   0.0
# school_city_New Orleans                       mean                   0.0
# school_city_New York                          mean                   0.0
# school_city_North Hills                       mean                     0
# school_city_Oakland                           mean                   0.0
# school_city_Other                             mean    0.9760765550239234
# school_city_Philadelphia                      mean                   0.0
# school_city_Phoenix                           mean  0.004784688995215311
# school_city_Portland                          mean                     0
# school_city_Richmond                          mean                   0.0
# school_city_Sacramento                        mean                     0
# school_city_San Francisco                     mean                     0
# school_city_Seattle                           mean                   0.0
# school_city_South Gate                        mean                   0.0
# school_city_Tulsa                             mean                   0.0
# ...                                                                  ...
# secondary_focus_area_Special Needs            mean   0.07655502392344497
# resource_type_Books                           mean   0.18660287081339713
# resource_type_Other                           mean   0.14354066985645933
# resource_type_Supplies                        mean   0.24401913875598086
# resource_type_Technology                      mean    0.4258373205741627
# resource_type_Trips                           mean                   0.0
# resource_type_Visitors                        mean                   0.0
# poverty_level_high poverty                    mean    0.3253588516746411
# poverty_level_highest poverty                 mean   0.41626794258373206
# poverty_level_low poverty                     mean                   0.0
# poverty_level_moderate poverty                mean    0.2583732057416268
# grade_level_Grades 3-5                        mean    0.3157894736842105
# grade_level_Grades 6-8                        mean   0.10047846889952153
# grade_level_Grades 9-12                       mean   0.11961722488038277
# grade_level_Grades PreK-2                     mean   0.46411483253588515
# total_price_including_optional_support_lowest mean   0.06220095693779904
# total_price_including_optional_support_low    mean    0.2631578947368421
# total_price_including_optional_support_medium mean   0.15311004784688995
# total_price_including_optional_support_high   mean    0.5215311004784688
# students_reached_lowest                       mean    0.3588516746411483
# students_reached_low                          mean   0.24401913875598086
# students_reached_medium                       mean   0.19617224880382775
# students_reached_high                         mean   0.20095693779904306
# eligible_double_your_impact_match_f           mean    0.9569377990430622
# eligible_double_your_impact_match_t           mean    0.0430622009569378
# label                                         mean     0.569377990430622
# scores                                        mean                     1
# students_reached                              mean   0.08268747740669853
# total_price_including_optional_support        mean  0.015323246162679424
# pred                                          mean                     1
#
# cluster                                                                 3
# index                                         mean     10930.816532258064
# school_city_Bakersfield                       mean  0.0020161290322580645
# school_city_Baltimore                         mean                    0.0
# school_city_Bronx                             mean    0.02620967741935484
# school_city_Brooklyn                          mean   0.016129032258064516
# school_city_Charlotte                         mean   0.016129032258064516
# school_city_Chicago                           mean    0.03024193548387097
# school_city_Columbus                          mean  0.0020161290322580645
# school_city_Dallas                            mean   0.014112903225806451
# school_city_Denver                            mean                      0
# school_city_Houston                           mean   0.004032258064516129
# school_city_Indianapolis                      mean    0.04032258064516129
# school_city_Las Vegas                         mean   0.012096774193548387
# school_city_Los Angeles                       mean    0.09475806451612903
# school_city_Memphis                           mean   0.004032258064516129
# school_city_N Hollywood                       mean   0.004032258064516129
# school_city_New Orleans                       mean  0.0020161290322580645
# school_city_New York                          mean   0.010080645161290322
# school_city_North Hills                       mean                      0
# school_city_Oakland                           mean   0.010080645161290322
# school_city_Other                             mean     0.6592741935483871
# school_city_Philadelphia                      mean  0.0020161290322580645
# school_city_Phoenix                           mean   0.010080645161290322
# school_city_Portland                          mean                      0
# school_city_Richmond                          mean   0.006048387096774193
# school_city_Sacramento                        mean                      0
# school_city_San Francisco                     mean                      0
# school_city_Seattle                           mean                    0.0
# school_city_South Gate                        mean                    0.0
# school_city_Tulsa                             mean   0.016129032258064516
# ...                                                                   ...
# secondary_focus_area_Special Needs            mean    0.05241935483870968
# resource_type_Books                           mean     0.1693548387096774
# resource_type_Other                           mean    0.08669354838709678
# resource_type_Supplies                        mean     0.2318548387096774
# resource_type_Technology                      mean     0.5060483870967742
# resource_type_Trips                           mean   0.006048387096774193
# resource_type_Visitors                        mean                    0.0
# poverty_level_high poverty                    mean                 0.3125
# poverty_level_highest poverty                 mean     0.5826612903225806
# poverty_level_low poverty                     mean   0.006048387096774193
# poverty_level_moderate poverty                mean    0.09879032258064516
# grade_level_Grades 3-5                        mean     0.3165322580645161
# grade_level_Grades 6-8                        mean    0.14919354838709678
# grade_level_Grades 9-12                       mean    0.10483870967741936
# grade_level_Grades PreK-2                     mean    0.42943548387096775
# total_price_including_optional_support_lowest mean    0.04435483870967742
# total_price_including_optional_support_low    mean                  0.125
# total_price_including_optional_support_medium mean    0.16532258064516128
# total_price_including_optional_support_high   mean     0.6653225806451613
# students_reached_lowest                       mean    0.28830645161290325
# students_reached_low                          mean     0.2923387096774194
# students_reached_medium                       mean    0.17137096774193547
# students_reached_high                         mean    0.24798387096774194
# eligible_double_your_impact_match_f           mean      0.905241935483871
# eligible_double_your_impact_match_t           mean    0.09475806451612903
# label                                         mean    0.46975806451612906
# scores                                        mean                      1
# students_reached                              mean    0.09616119267741993
# total_price_including_optional_support        mean    0.02038026295362904
# pred                                          mean                      1
#
# [232 rows x 4 columns]

# %%
pp.summarize_kmeans_features(pred_hw5[focus], 'cluster')
# Out:
# cluster                                                              0  \
# primary_focus_subject_Applied Sciences      mean   0.02702702702702703
# primary_focus_subject_Character Education   mean  0.010810810810810811
# primary_focus_subject_CivicsGovernment      mean                   0.0
# primary_focus_subject_CollegeCareer Prep    mean                   0.0
# primary_focus_subject_Community Service     mean  0.005405405405405406
# primary_focus_subject_ESL                   mean  0.021621621621621623
# primary_focus_subject_Early Development     mean  0.021621621621621623
# primary_focus_subject_Economics             mean  0.005405405405405406
# primary_focus_subject_Environmental Science mean  0.016216216216216217
# primary_focus_subject_Extracurricular       mean  0.005405405405405406
# primary_focus_subject_Foreign Languages     mean  0.005405405405405406
# primary_focus_subject_GymFitness            mean                   0.0
# primary_focus_subject_HealthLife Science    mean  0.005405405405405406
# primary_focus_subject_HealthWellness        mean  0.005405405405405406
# primary_focus_subject_HistoryGeography      mean  0.010810810810810811
# primary_focus_subject_Literacy              mean    0.4756756756756757
# primary_focus_subject_LiteratureWriting     mean    0.1891891891891892
# primary_focus_subject_Mathematics           mean  0.010810810810810811
# primary_focus_subject_Music                 mean  0.016216216216216217
# primary_focus_subject_Nutrition             mean                     0
# primary_focus_subject_Other                 mean   0.02702702702702703
# primary_focus_subject_Parent Involvement    mean                     0
# primary_focus_subject_Performing Arts       mean  0.010810810810810811
# primary_focus_subject_Social Sciences       mean  0.005405405405405406
# primary_focus_subject_Special Needs         mean   0.08648648648648649
# primary_focus_subject_Sports                mean                   0.0
# primary_focus_subject_Visual Arts           mean   0.03783783783783784
# primary_focus_area_Applied Learning         mean   0.07027027027027027
# primary_focus_area_HealthSports             mean  0.005405405405405406
# primary_focus_area_HistoryCivics            mean  0.021621621621621623
# primary_focus_area_LiteracyLanguage         mean    0.6918918918918919
# primary_focus_area_MathScience              mean   0.05945945945945946
# primary_focus_area_MusicThe Arts            mean   0.06486486486486487
# primary_focus_area_Special Needs            mean   0.08648648648648649
#
# cluster                                                             1  \
# primary_focus_subject_Applied Sciences      mean  0.05128205128205128
# primary_focus_subject_Character Education   mean                  0.0
# primary_focus_subject_CivicsGovernment      mean                  0.0
# primary_focus_subject_CollegeCareer Prep    mean                  0.0
# primary_focus_subject_Community Service     mean                  0.0
# primary_focus_subject_ESL                   mean                  0.0
# primary_focus_subject_Early Development     mean                  0.0
# primary_focus_subject_Economics             mean                  0.0
# primary_focus_subject_Environmental Science mean  0.10256410256410256
# primary_focus_subject_Extracurricular       mean                  0.0
# primary_focus_subject_Foreign Languages     mean                  0.0
# primary_focus_subject_GymFitness            mean                  0.0
# primary_focus_subject_HealthLife Science    mean  0.05128205128205128
# primary_focus_subject_HealthWellness        mean                  0.0
# primary_focus_subject_HistoryGeography      mean                  0.0
# primary_focus_subject_Literacy              mean                  0.0
# primary_focus_subject_LiteratureWriting     mean                  0.0
# primary_focus_subject_Mathematics           mean   0.7948717948717948
# primary_focus_subject_Music                 mean                  0.0
# primary_focus_subject_Nutrition             mean                    0
# primary_focus_subject_Other                 mean                  0.0
# primary_focus_subject_Parent Involvement    mean                    0
# primary_focus_subject_Performing Arts       mean                  0.0
# primary_focus_subject_Social Sciences       mean                  0.0
# primary_focus_subject_Special Needs         mean                  0.0
# primary_focus_subject_Sports                mean                  0.0
# primary_focus_subject_Visual Arts           mean                  0.0
# primary_focus_area_Applied Learning         mean                  0.0
# primary_focus_area_HealthSports             mean                  0.0
# primary_focus_area_HistoryCivics            mean                  0.0
# primary_focus_area_LiteracyLanguage         mean                  0.0
# primary_focus_area_MathScience              mean                  1.0
# primary_focus_area_MusicThe Arts            mean                  0.0
# primary_focus_area_Special Needs            mean                  0.0
#
# cluster                                                              2  \
# primary_focus_subject_Applied Sciences      mean  0.023923444976076555
# primary_focus_subject_Character Education   mean  0.004784688995215311
# primary_focus_subject_CivicsGovernment      mean  0.004784688995215311
# primary_focus_subject_CollegeCareer Prep    mean  0.019138755980861243
# primary_focus_subject_Community Service     mean  0.004784688995215311
# primary_focus_subject_ESL                   mean  0.009569377990430622
# primary_focus_subject_Early Development     mean  0.023923444976076555
# primary_focus_subject_Economics             mean  0.009569377990430622
# primary_focus_subject_Environmental Science mean  0.004784688995215311
# primary_focus_subject_Extracurricular       mean                   0.0
# primary_focus_subject_Foreign Languages     mean                   0.0
# primary_focus_subject_GymFitness            mean  0.004784688995215311
# primary_focus_subject_HealthLife Science    mean  0.028708133971291867
# primary_focus_subject_HealthWellness        mean  0.019138755980861243
# primary_focus_subject_HistoryGeography      mean  0.028708133971291867
# primary_focus_subject_Literacy              mean   0.44019138755980863
# primary_focus_subject_LiteratureWriting     mean    0.1674641148325359
# primary_focus_subject_Mathematics           mean  0.009569377990430622
# primary_focus_subject_Music                 mean  0.023923444976076555
# primary_focus_subject_Nutrition             mean                     0
# primary_focus_subject_Other                 mean  0.023923444976076555
# primary_focus_subject_Parent Involvement    mean                     0
# primary_focus_subject_Performing Arts       mean  0.009569377990430622
# primary_focus_subject_Social Sciences       mean  0.004784688995215311
# primary_focus_subject_Special Needs         mean   0.08133971291866028
# primary_focus_subject_Sports                mean                   0.0
# primary_focus_subject_Visual Arts           mean   0.05263157894736842
# primary_focus_area_Applied Learning         mean   0.07655502392344497
# primary_focus_area_HealthSports             mean  0.023923444976076555
# primary_focus_area_HistoryCivics            mean   0.04784688995215311
# primary_focus_area_LiteracyLanguage         mean    0.6172248803827751
# primary_focus_area_MathScience              mean   0.06698564593301436
# primary_focus_area_MusicThe Arts            mean    0.0861244019138756
# primary_focus_area_Special Needs            mean   0.08133971291866028
#
# cluster                                                               3
# primary_focus_subject_Applied Sciences      mean                    0.0
# primary_focus_subject_Character Education   mean   0.006048387096774193
# primary_focus_subject_CivicsGovernment      mean  0.0020161290322580645
# primary_focus_subject_CollegeCareer Prep    mean    0.02217741935483871
# primary_focus_subject_Community Service     mean  0.0020161290322580645
# primary_focus_subject_ESL                   mean   0.020161290322580645
# primary_focus_subject_Early Development     mean    0.03225806451612903
# primary_focus_subject_Economics             mean                    0.0
# primary_focus_subject_Environmental Science mean                    0.0
# primary_focus_subject_Extracurricular       mean   0.004032258064516129
# primary_focus_subject_Foreign Languages     mean   0.010080645161290322
# primary_focus_subject_GymFitness            mean   0.012096774193548387
# primary_focus_subject_HealthLife Science    mean  0.0020161290322580645
# primary_focus_subject_HealthWellness        mean   0.014112903225806451
# primary_focus_subject_HistoryGeography      mean   0.020161290322580645
# primary_focus_subject_Literacy              mean     0.4717741935483871
# primary_focus_subject_LiteratureWriting     mean    0.19153225806451613
# primary_focus_subject_Mathematics           mean                    0.0
# primary_focus_subject_Music                 mean   0.008064516129032258
# primary_focus_subject_Nutrition             mean                      0
# primary_focus_subject_Other                 mean   0.034274193548387094
# primary_focus_subject_Parent Involvement    mean                      0
# primary_focus_subject_Performing Arts       mean   0.012096774193548387
# primary_focus_subject_Social Sciences       mean   0.018145161290322582
# primary_focus_subject_Special Needs         mean    0.06653225806451613
# primary_focus_subject_Sports                mean   0.006048387096774193
# primary_focus_subject_Visual Arts           mean    0.04435483870967742
# primary_focus_area_Applied Learning         mean    0.10080645161290322
# primary_focus_area_HealthSports             mean    0.03225806451612903
# primary_focus_area_HistoryCivics            mean    0.04032258064516129
# primary_focus_area_LiteracyLanguage         mean     0.6935483870967742
# primary_focus_area_MathScience              mean  0.0020161290322580645
# primary_focus_area_MusicThe Arts            mean    0.06451612903225806
# primary_focus_area_Special Needs            mean    0.06653225806451613

# %%
pp.cluster_size(pred_hw5, 'cluster')
# Out:
# cluster
# 0    601
# 1    484
# Name: cluster, dtype: int64

# %%
pp.plot_2d_cluster(pred_hw5, 'cluster','students_reached', 'total_price_including_optional_support')

# %%
dt = DecisionTreeClassifier(max_depth = 5)
dt.fit(pred_hw5[features], pred_hw5['cluster'])
pp.graph_tree(dt, features, 'hw5tree.png')
Image('hw5tree.png')

# %%
features.remove('primary_focus_area_LiteracyLanguage')
dt = DecisionTreeClassifier(max_depth = 5)
dt.fit(pred_hw5[features], pred_hw5['cluster'])
pp.graph_tree(dt, features, 'hw5tree.png')
Image('hw5tree.png')
